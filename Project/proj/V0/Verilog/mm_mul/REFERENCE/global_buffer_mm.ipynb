# 6.1947 3.6634 6.5087 6.1125 2.4081 2.0604 7.4628 4.0286
# 7.6728 7.6041 3.1913 7.4148 7.7821 2.5957 3.3259 4.2206
# 7.6253 4.5989 6.0184 4.7112 6.2319 7.9209 3.0650 2.9472
# 5.9424 4.6123 6.4475 2.2172 2.1610 4.4626 3.7768 3.5799
# 2.9720 3.3228 4.5196 2.6867 5.4281 3.9807 2.9123 2.2058
# ...

# %%
for i in range(8):
    for j in range(8):
        print(B_str[i*8+j], end=" ")
    print()
for i in range(8):
    for j in range(8):
        f = struct.unpack('!f', bytes.fromhex(B_str[i*8+j]))[0]
        print("{:.4f}".format(f), end=" ")
    print()
# Out:
# 40ba21a3 40878226 4014ad90 40539146 40cf4f7b 4028b352 400db3cc 40b2cdbe
# 40575b85 40c101d3 4057c829 40421398 404f5320 401433fe 4076e7fb 405640f6
# 40595f01 406d58e4 40c0be0c 40968417 402e0fce 40ea6689 40c776d4 4008ee66
# 4084c719 40e4577c 40743f0d 4041c78e 40e09ad0 40454711 4013666b 404de301
# 40ad2faa 4048dd97 401a3ab2 40b499d0 4029ecab 408802f0 40943a80 400b9438
# 403a16a7 40025207 40d03668 408c7b51 40a17f67 40d8a135 409cb497 407c05dd
# 40f3eb5d 40afec4c 40b9c617 40ced771 40809c3b 403e53e6 40aab765 40e81545
# 408bf013 4065b771 40339681 4061fd17 407437e0 40f6308c 401582bc 406756f5
# 5.8166 4.2346 2.3231 3.3057 6.4785 2.6359 2.2141 5.5876
# 3.3650 6.0315 3.3716 3.0324 3.2394 2.3157 3.8579 3.3477
# 3.3964 3.7086 6.0232 4.7036 2.7197 7.3250 6.2333 2.1396
# 4.1493 7.1357 3.8163 3.0278 7.0189 3.0825 2.3031 3.2170
# 5.4121 3.1385 2.4098 5.6438 2.6551 4.2504 4.6321 2.1809
# 2.9076 2.0363 6.5066 4.3901 5.0468 6.7697 4.8970 3.9379
# 7.6225 5.4976 5.8054 6.4638 4.0191 2.9739 5.3349 7.2526
# ...

# %%
for i in range(8):
    for j in range(8):
        print(C_str[i*8+j], end=" ")
    print()
for i in range(8):
    for j in range(8):
        f = struct.unpack('!f', bytes.fromhex(C_str[i*8+j]))[0]
        print("{:.4f}".format(f), end=" ")
    print()
# Out:
# 43536ec9 4336a7f3 433255c7 433f9b3a 433ea528 433ec6a9 432e7ed7 43373a15
# 43353e7a 432d2788 430d7f84 431d7634 432212c8 431677d1 430fe754 431772ed
# 433d5ab6 433752ea 43231c96 4325cef4 432ec351 4328b373 4318f74a 432284f3
# 434d4ba1 434e3e54 431dc6b0 433199f5 43464c65 4331138d 431fa7e4 432594c7
# 4340d3f1 4333152d 433411f4 4335e3bb 4341d207 43494175 432de216 4323b37a
# 43164c64 430e329f 430ede1e 430b82f3 430fa2e2 431e937f 43089f44 430430b0
# 42ff8693 42eb4228 42eb52cf 42f8091f 42e7952b 43049116 42ee2c16 42cd4d8f
# 4318a3d3 4304ff07 430b66c0 4312e57d 430973c0 43192a9f 43074efe 42fff8b2
# 211.4328 182.6561 178.3351 191.6064 190.6451 190.7760 174.4955 183.2269
# 181.2440 173.1544 141.4981 157.4617 162.0734 150.4680 143.9036 151.4489
# 189.3543 183.3239 163.1117 165.8084 174.7630 168.7010 152.9660 162.5193
# 205.2954 206.2435 157.7761 177.6014 198.2984 177.0764 159.6558 165.5812
# 192.8279 179.0827 180.0701 181.8896 193.8204 201.2557 173.8831 163.7011
# ...
